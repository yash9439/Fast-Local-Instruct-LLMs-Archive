# %%
# !pip install transformers==4.29.2
# !pip install accelerate==0.19.0
# !pip install torch==2.0.0
# !pip install einops==0.6.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 46.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 28.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 109.8 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 8.8 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 72.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 70.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 98.6 MB/s eta 0:00:00
# ...

# %%
import torch
from transformers import AutoTokenizer, pipeline


tokenizer = AutoTokenizer.from_pretrained(
    "h2oai/h2ogpt-gm-oasst1-en-2048-falcon-7b-v3",
    use_fast=False,
    padding_side="left",
    trust_remote_code=True,
)

generate_text = pipeline(
    model="h2oai/h2ogpt-gm-oasst1-en-2048-falcon-7b-v3",
    tokenizer=tokenizer,
    torch_dtype=torch.float16,
    trust_remote_code=True,
    use_fast=False,
    device_map={"": "cuda:0"},
)

res = generate_text(
    "Why is drinking water so healthy?",
    min_new_tokens=2,
    max_new_tokens=1024,
    do_sample=False,
    num_beams=1,
    temperature=float(0.3),
    repetition_penalty=float(1.2),
    renormalize_logits=True
)
print(res[0]["generated_text"])
# Out:
# ...
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b:
# - configuration_RW.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...
# A new version of the following files was downloaded from https://huggingface.co/h2oai/h2ogpt-gm-oasst1-en-2048-falcon-7b-v3:
# - h2oai_pipeline.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b:
# - modelling_RW.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
print(generate_text.preprocess("Why is drinking water so healthy?")["prompt_text"])
# Out:
# <|prompt|>Why is drinking water so healthy?<|endoftext|><|answer|>

# %%
res = generate_text(
    "What are the recent advancement in the field of NLP?",
    min_new_tokens=2,
    max_new_tokens=1024,
    do_sample=False,
    num_beams=1,
    temperature=float(0.3),
    repetition_penalty=float(1.2),
    renormalize_logits=True
)
print(res[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# There have been several advancements in the field of Natural Language Processing (NLP) over the past few years. Here are some examples:
#
# 1. Deep Learning: The use of deep learning algorithms has revolutionized NLP, particularly in areas such as speech recognition and natural language understanding. These techniques allow computers to learn complex patterns from large amounts of data, making them more accurate and efficient than traditional methods.
#
# 2. Generative Pre-training: This technique involves pre-training a neural network on a large corpus of text data, followed by fine-tuning it on specific tasks. It allows for better performance on downstream tasks like machine translation and question answering.
#
# ...

# %%
res = generate_text(
    "Give me python code to print number from 1 to 100?",
    min_new_tokens=2,
    max_new_tokens=1024,
    do_sample=False,
    num_beams=1,
    temperature=float(0.3),
    repetition_penalty=float(1.2),
    renormalize_logits=True
)
print(res[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Here is a simple Python program that prints the numbers from 1 to 100:
#
# ```python
# print("1", end="")
# for i in range(101, 0, -1):
#     print(i, end="")
# ```
#
# This program uses the for loop to iterate over the range of numbers from 1 to 100. The end keyword at the end of each line causes the output to be printed on the same line as the previous line. This results in a list of numbers being printed from 1 to 100.

# %%
res = generate_text(
    "Give me python code to print number from 1 to 100?",
    min_new_tokens=2,
    max_new_tokens=1024,
    do_sample=False,
    num_beams=1,
    temperature=float(0.1),
    repetition_penalty=float(1.2),
    renormalize_logits=True
)
print(res[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Here is a simple Python program that prints the numbers from 1 to 100:
#
# ```python
# print("1", end="")
# for i in range(101, 0, -1):
#     print(i, end="")
# ```
#
# This program uses the for loop to iterate over the range of numbers from 1 to 100. The end keyword at the end of each line causes the output to be printed on the same line as the previous line. This results in a list of numbers being printed from 1 to 100.

# %%
res = generate_text(
    "Give me python code to print number from 1 to 100?",
    min_new_tokens=2,
    max_new_tokens=1024,
    do_sample=False,
    num_beams=2,
    temperature=float(0),
    repetition_penalty=float(1.2),
    renormalize_logits=True
)
print(res[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Here's a simple Python program that prints the numbers from 1 to 100:
#
# ```python
# for i in range(1, 101):
#     print(i)
# ```
#
# This program uses the `range` function to generate a list of numbers from 1 to 100. The `for` loop then iterates over this list and prints each number using the `print` function.
